# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
weather = pd.read_csv('Weather Data.csv')

# %%
weather
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
weather1 = pd.read_csv('Madrid Daily Weather 1997-2015.csv')

# %%
weather1
# Out:
#              CET  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 0     1997-01-01               7.0                4.0               2.0
# 1     1997-01-02               7.0                3.0               0.0
# 2     1997-01-03               5.0                3.0               2.0
# 3     1997-01-04               7.0                3.0              -1.0
# 4     1997-01-05               2.0                0.0              -1.0
# ...          ...               ...                ...               ...
# 6807  2015-12-27              14.0                7.0              -1.0
# 6808  2015-12-28              15.0                8.0               2.0
# 6809  2015-12-29              11.0                8.0               5.0
# 6810  2015-12-30               9.0                8.0               6.0
# 6811  2015-12-31              12.0               10.0               7.0
#
#       Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity   Mean Humidity  \
# ...

# %%
weather1["CET"] = pd.to_datetime(weather1["CET"])

# %%
weather1
# Out:
#             CET  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 0    1997-01-01               7.0                4.0               2.0
# 1    1997-01-02               7.0                3.0               0.0
# 2    1997-01-03               5.0                3.0               2.0
# 3    1997-01-04               7.0                3.0              -1.0
# 4    1997-01-05               2.0                0.0              -1.0
# ...         ...               ...                ...               ...
# 6807 2015-12-27              14.0                7.0              -1.0
# 6808 2015-12-28              15.0                8.0               2.0
# 6809 2015-12-29              11.0                8.0               5.0
# 6810 2015-12-30               9.0                8.0               6.0
# 6811 2015-12-31              12.0               10.0               7.0
#
#       Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity   Mean Humidity  \
# ...

# %%
weather1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6812 entries, 0 to 6811
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CET                          6812 non-null   datetime64[ns]
#  1   Max TemperatureC             6810 non-null   float64
#  2   Mean TemperatureC            6809 non-null   float64
#  3   Min TemperatureC             6810 non-null   float64
#  4   Dew PointC                   6810 non-null   float64
#  5   MeanDew PointC               6810 non-null   float64
#  6   Min DewpointC                6810 non-null   float64
#  7   Max Humidity                 6810 non-null   float64
#  8    Mean Humidity               6810 non-null   float64
#  9    Min Humidity                6810 non-null   float64
#  10   Max Sea Level PressurehPa   6812 non-null   int64
#  11   Mean Sea Level PressurehPa  6812 non-null   int64
# ...

# %%
#How would you find the hottest and coldest days in Madrid based on "Max TemperatureC" and "Min TempsseratureC"?

# %%
hottest_temp = weather1['Max TemperatureC'].max()
print(hottest_temp)
# Out:
# 41.0

# %%
hottest_day = weather1.groupby('Year')['Max TemperatureC'].max()
s = hottest_day.idxmax()
a = hottest_day.max()
print(s)
print(a)
# Out:
# 2012
# 41.0

# %%
hottest_day = weather1.loc[weather1['Max TemperatureC'].idxmax()]
print(hottest_day)
# Out:
# CET                            2012-08-10 00:00:00
# Max TemperatureC                              41.0
# Mean TemperatureC                             30.0
# Min TemperatureC                              20.0
# Dew PointC                                     7.0
# MeanDew PointC                                 5.0
# Min DewpointC                                  3.0
# Max Humidity                                  38.0
#  Mean Humidity                                20.0
#  Min Humidity                                  6.0
#  Max Sea Level PressurehPa                    1023
#  Mean Sea Level PressurehPa                   1021
#  Min Sea Level PressurehPa                    1014
#  Max VisibilityKm                             19.0
#  Mean VisibilityKm                            12.0
#  Min VisibilitykM                             10.0
#  Max Wind SpeedKm/h                             42
#  Mean Wind SpeedKm/h                            10
# ...

# %% [markdown]
# #This result tells us that the hottest day (with the maximum temperature) had a maximum temperature of 41.0 degrees Celsius, and it occurred on August 10, 2012.

# %%
Coldest_day = weather1['Min TemperatureC'].min()
print(Coldest_day)
# Out:
# -10.0

# %%
Coldest_day = weather1.loc[weather1['Min TemperatureC'].idxmin()]
print(Coldest_day)
# Out:
# CET                            2001-12-16 00:00:00
# Max TemperatureC                               5.0
# Mean TemperatureC                             -2.0
# Min TemperatureC                             -10.0
# Dew PointC                                    -8.0
# MeanDew PointC                               -11.0
# Min DewpointC                                -13.0
# Max Humidity                                  86.0
#  Mean Humidity                                63.0
#  Min Humidity                                 26.0
#  Max Sea Level PressurehPa                    1024
#  Mean Sea Level PressurehPa                   1022
#  Min Sea Level PressurehPa                    1021
#  Max VisibilityKm                              NaN
#  Mean VisibilityKm                             NaN
#  Min VisibilitykM                              NaN
#  Max Wind SpeedKm/h                             10
#  Mean Wind SpeedKm/h                             5
# ...

# %% [markdown]
# This temperature reading indicates that December 16, 2001, was the coldest day in the dataset, with a minimum temperature of -10.0°C.

# %%
#What is the average daily temperature range in this dataset?

# %%
weather1.describe()
# Out:
#                                  CET  Max TemperatureC  Mean TemperatureC  \
# count                           6812       6810.000000        6809.000000
# mean   2006-08-07 00:57:55.278919680         21.039648          14.658687
# min              1997-01-01 00:00:00          0.000000          -3.000000
# 25%              2001-12-05 18:00:00         13.000000           8.000000
# 50%              2006-09-03 12:00:00         20.000000          14.000000
# 75%              2011-05-03 06:00:00         29.000000          21.000000
# max              2015-12-31 00:00:00         41.000000          32.000000
# std                              NaN          8.867187           7.580461
#
#        Min TemperatureC   Dew PointC  MeanDew PointC  Min DewpointC  \
# count       6810.000000  6810.000000     6810.000000    6810.000000
# mean           8.640529     8.120705        4.976211       1.451248
# min          -10.000000   -12.000000      -15.000000     -22.000000
# ...

# %%
temp_range = (weather1['Max TemperatureC'] - weather1['Min TemperatureC'])
average_temp_range = (temp_range).mean()
print("Average daily temperature range:", average_temp_range)
# Out:
# Average daily temperature range: 12.399118942731278

# %% [markdown]
# #The average daily temperature range in this data is approximately 12.40C
# #This means that, on average, the temperature varies by about 12.40°C between the highest and lowest points of the day

# %%
#How would you visualize the trend of "Mean TemperatureC" over time?

# %%
plt.figure(figsize=(10, 6))
plt.plot(weather1['CET'], weather1['Mean TemperatureC'])
plt.xlabel('CET')
plt.ylabel('Mean TemperatureC')
plt.title('Mean Temperature Trend Over Time')
# Out:
# Text(0.5, 1.0, 'Mean Temperature Trend Over Time')

# %% [markdown]
# #The plot shows a clear cyclic pattern, where temperatures rise and fall in a yearly cycle.

# %%
#How would you plot a histogram of "Precipitationmm" to analyze rainfall distribution?

# %%
val = weather1['Precipitationmm']
plt.figure(figsize=(10, 5))
plt.hist(val,bins=20)
plt.xlabel('Precipitation (mm)')
plt.ylabel('Frequency')
plt.title('Precipitationm')
plt.savefig('Histogram')

# %% [markdown]
# #This confirms that Madrid has a predominantly dry climate, with rainfall occurring in short, infrequent bursts.

# %%
#How would you find the correlation between temperature and humidity levels?

# %%
corr_btw_maxT_and_maxH = weather1['Max TemperatureC'].corr(weather1['Max Humidity'])
corr_btw_meanT_and_meanH = weather1['Mean TemperatureC'].corr(weather1[' Mean Humidity'])
corr_btw_minT_and_meanH = weather1['Min TemperatureC'].corr(weather1[' Min Humidity'])
print(corr_btw_maxT_and_maxH)
print(corr_btw_meanT_and_meanH)
print(corr_btw_minT_and_meanH)
# Out:
# -0.7181837118562038
# -0.7428905212610359
# -0.48008209218114745

# %% [markdown]
# #As temperature increases, humidity tends to decrease.

# %%
correlations = {
    'Max Temp vs Max Humidity': weather1['Max TemperatureC'].corr(weather1['Max Humidity']),
    'Mean Temp vs Mean Humidity': weather1['Mean TemperatureC'].corr(weather1[' Mean Humidity']),
    'Min Temp vs Mean Humidity': weather1['Min TemperatureC'].corr(weather1[' Min Humidity'])
}
for key, value in correlations.items():
    print(f"{key}: {value}")
# Out:
# Max Temp vs Max Humidity: -0.7181837118562038
# Mean Temp vs Mean Humidity: -0.7428905212610359
# Min Temp vs Mean Humidity: -0.48008209218114745

# %% [markdown]
# ANOTHER QUESTIONS

# %%
#What is the average, median, and standard deviation of the mean temperature over the entire dataset?

# %%
weather1.describe()
# Out:
#                                  CET  Max TemperatureC  Mean TemperatureC  \
# count                           6812       6810.000000        6809.000000
# mean   2006-08-07 00:57:55.278919680         21.039648          14.658687
# min              1997-01-01 00:00:00          0.000000          -3.000000
# 25%              2001-12-05 18:00:00         13.000000           8.000000
# 50%              2006-09-03 12:00:00         20.000000          14.000000
# 75%              2011-05-03 06:00:00         29.000000          21.000000
# max              2015-12-31 00:00:00         41.000000          32.000000
# std                              NaN          8.867187           7.580461
#
#        Min TemperatureC   Dew PointC  MeanDew PointC  Min DewpointC  \
# count       6810.000000  6810.000000     6810.000000    6810.000000
# mean           8.640529     8.120705        4.976211       1.451248
# min          -10.000000   -12.000000      -15.000000     -22.000000
# ...

# %%
#What was the hottest and coldest year on average?

# %%
hottest_and_coldest_year_on_average = weather1.groupby('CET')['Mean TemperatureC'].mean()
hottest_year = hottest_and_coldest_year_on_average.idxmax()
hottest_temp = hottest_and_coldest_year_on_average .max()
coldest_year = hottest_and_coldest_year_on_average.idxmin()
coldest_temp = hottest_and_coldest_year_on_average.min()
print(f"The hottest year on record is {hottest_year} with a mean temperature of {hottest_temp}°C")
print(f"The coldest year on record is {coldest_year} with a mean temperature of {coldest_temp}°C")
# Out:
# The hottest year on record is 1997-07-31 00:00:00 with a mean temperature of 32.0°C
# The coldest year on record is 2001-12-22 00:00:00 with a mean temperature of -3.0°C

# %% [markdown]
# Our temperature records show that July 1997 was a warm month, with temperatures hitting 32.0°C, while December 2001 was much colder, at -3.0°C."

# %%
#How does the difference between max and min temperature vary seasonally?

# %%
weather1["Temp_Diff"] = weather1["Max TemperatureC"] - weather1["Min TemperatureC"]


seasonal_temp_diff = weather1.groupby("CET")["Temp_Diff"]

print("Temperature Difference by Season:").sort_values()
print(seasonal_temp_diff)
# Out:
# Average Temperature Difference by Season:
# ...
